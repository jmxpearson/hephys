# %% [markdown]
# # Time-Frequency Analysis of mean LFP across channels
#
# Let's take the mean across channels, then analyze the resulting LFP series.

# %% [markdown]
# To begin, do the usual bookkeeping and imports.

# %%
import numpy as np
import pandas as pd
import physutils as phys
import physutils.bootstrap as boot
import physutils.tf as tf
import matplotlib.pyplot as plt
import hephys.dbio as dbio
# %matplotlib inline

# %% [markdown]
# Fetch some LFP data to play with:

# %%
import os
dbname = os.path.expanduser('~/data/bartc/plexdata/bartc.hdf5')
dtup = 17, 2

# %%
lfp = dbio.fetch_all_such_LFP(dbname, *dtup)

# %% [markdown]
# Now censor lfp, zscore to normalize,and average across channels:

# %%
lfpm = phys.LFPset(lfp.censor().zscore().mean(axis=1))

# %% [markdown]
# Bandlimit to < 50 Hz.

# %%
lfpm = lfpm.bandlimit([(0.1, 50)])
lfpm.columns = 0

# %% [markdown]
# Get some example events from a behavioral task, the Balloon Analogue Risk Task (BART):

# %%
evt = dbio.fetch_all_such(dbname, 'events', *dtup)

# %% [markdown]
# Let's compare responses to two sets of events, voluntary stops and unexpected balloon pops:

# %%
stops = evt['stop inflating'].dropna()
pops = evt['popped'].dropna()

# %% [markdown]
# We'll look at a window that begins 1.5 seconds before the event and ends half a second after.

# %%
Tpre = -1.5
Tpost = 0.5

# %%
baseline_interval = (-1.5, -1.35)
nf = phys.norm_by_trial(baseline_interval, method='subtraction')
wav_normed, fig = lfpm.avg_time_frequency(lfpm.dataframe.columns[0], 
                                          stops, Tpre, Tpost, 
                                          method='wav', 
                                          normfun=nf,
                                          clim=(-2, 2))

# %% [markdown]
# Let's try a contrast plot between two event types:

# %%
contr_tf, fig = lfpm.contrast_time_frequency(0, [stops, pops], Tpre, Tpost, method='wav',
                            normfun=phys.norm_by_trial(baseline_interval, method='subtraction'))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-cd91098c58d2> in <module>()
#       1 contr_tf, fig = lfpm.contrast_time_frequency(0, [stops, pops], Tpre, Tpost, method='wav',
# ----> 2                             normfun=phys.norm_by_trial(baseline_interval, method='subtraction'))
#
# /home/jmp33/code/physutils/classes/lfpclasses.pyc in contrast_time_frequency(self, channel, times, Tpre, Tpost, method, doplot, **kwargs)
#     136         method 'spec': window length (in s) and fraction overlap
#     137         """
# --> 138         series = self.dataframe[channel]
#     139         if method == 'wav':
#     140             callback = tf.continuous_wavelet
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1682             return self._getitem_multilevel(key)
#    1683         else:
# -> 1684             return self._getitem_column(key)
#    1685
#    1686     def _getitem_column(self, key):
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    1689         # get column
#    1690         if self.columns.is_unique:
# -> 1691             return self._get_item_cache(key)
#    1692
#    1693         # duplicate columns & possible reduce dimensionaility
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1050         res = cache.get(item)
#    1051         if res is None:
# -> 1052             values = self._data.get(item)
#    1053             res = self._box_item_values(item, values)
#    1054             cache[item] = res
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/internals.pyc in get(self, item)
#    2535
#    2536             if not isnull(item):
# -> 2537                 loc = self.items.get_loc(item)
#    2538             else:
#    2539                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/index.pyc in get_loc(self, key)
#    1154         loc : int if unique index, possibly slice or mask if not
#    1155         """
# -> 1156         return self._engine.get_loc(_values_from_object(key))
#    1157
#    1158     def get_value(self, series, key):
#
# /usr/local/lib/python2.7/dist-packages/pandas/index.so in pandas.index.IndexEngine.get_loc (pandas/index.c:3353)()
#
# /usr/local/lib/python2.7/dist-packages/pandas/index.so in pandas.index.IndexEngine.get_loc (pandas/index.c:3233)()
#
# /usr/local/lib/python2.7/dist-packages/pandas/hashtable.so in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:11148)()
#
# /usr/local/lib/python2.7/dist-packages/pandas/hashtable.so in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:11101)()
#
# KeyError: 0

# %%
def plot_diff_map(img, taxis, faxis):
    ax = plt.figure().add_subplot(111)
    extent = (taxis[0], taxis[-1], faxis[0], faxis[-1])
    im = tf.NonUniformImage(ax, interpolation=None, extent=extent)
    im.set_data(taxis, faxis, img.T)
    ax.set_xlim(extent[0], extent[1])
    ax.set_ylim(extent[2], extent[3])
    ax.images.append(im)
    plt.colorbar(im)

# %%
series = lfpm.dataframe[0]
tffun = tf.continuous_wavelet
t0 = pd.DataFrame({'time':stops, 'label':0})
t1 = pd.DataFrame({'time':pops, 'label':1})
alltimes = pd.concat([t0, t1])
events = alltimes['time']
spectra, taxis, faxis = tf._per_event_time_frequency(series, tffun, events, Tpre, Tpost, normfun=phys.norm_by_trial(baseline_interval, method='subtraction'))

# %%
thresh = 1.0
labels = alltimes['label']
pos = boot.make_thresholded_diff(spectra, labels, hi=thresh)
neg = boot.make_thresholded_diff(spectra, labels, lo=-thresh)

# %%
plot_diff_map(pos.data, taxis, faxis)
plot_diff_map(pos, taxis, faxis)
plot_diff_map(neg, taxis, faxis)

# %% [markdown]
# Now see whether any of the hot or cold spots is significant:

# %%
# %%time
nf = phys.norm_by_trial(baseline_interval, method='subtraction')
contr_tf, fig = lfpm.contrast_time_frequency(0, [stops, pops], Tpre, Tpost, 
                                             method='wav',
                                             normfun=nf)
mcontr, fig = lfpm.significant_time_frequency(0, [stops, pops], 
                                             Tpre, Tpost, thresh=1., 
                                             niter=100, method='wav', 
                                             doplot=True, 
                                             normfun=nf)
# Out:
# CPU times: user 1min 40s, sys: 52 ms, total: 1min 40s
# Wall time: 1min 40s
